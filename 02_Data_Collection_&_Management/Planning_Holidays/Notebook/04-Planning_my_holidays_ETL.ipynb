# %% [markdown]
# # M3 Data collection and management : project
# ## Planning my next holidays ☀️
#
# Let's put your dataset in a postgreSQL database on Amazon RDS ! Then, you can use the SQL syntax to make requests and decide where you'll go for your holidays 😎

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os
import boto3

# %% [markdown]
# 1. Read the .csv files containing information about cities and hotels

# %%
df_weather = pd.read_csv('weather_cities.csv', index_col = 0)
df_weather.head()
# Out:
#    city_id  city_name        lat       lon  temperature main_weather  \
# 0       33    Bayonne  43.493338 -1.475099        18.51       Clouds
# 1       32   Biarritz  43.471144 -1.552727        17.88       Clouds
# 2       27  Collioure  42.525050  3.083155        17.51        Clear
# 3       15   Grenoble  45.187560  5.735782        17.32       Clouds
# 4       19     Cassis  43.214036  5.539632        17.25        Clear
#
#    humidity  expected_rain  wind_speed  UV_indice  rank  inverted_rank
# 0     58.43         0.5712        1.68       1.75     1             35
# 1     61.00         0.6106        1.73       1.74     2             34
# 2     64.29         0.1631        2.40       1.82     3             33
# 3     48.86         0.0000        0.86       1.56     4             32
# 4     61.71         1.5052        2.15       1.76     5             31

# %%
df_list_hotels = pd.read_csv('list_hotels.csv', index_col = 0)
df_list_hotels.head()
# Out:
#    city_id city_name  hotel id                    hotel name  \
# 0       33   Bayonne         0             Hôtel Le Bayonne
# 1       33   Bayonne         1          ibis budget Bayonne
# 2       33   Bayonne         2   Okko Hotels Bayonne Centre
# 3       33   Bayonne         3            Hotel Cote Basque
# 4       33   Bayonne         4   Hôtel Villa KOEGUI Bayonne
#
#                                            hotel url   latitude  longitude  \
# 0  https://www.booking.com/hotel/fr/le-bayonne-ha...  43.485026  -1.475371
# 1  https://www.booking.com/hotel/fr/ibis-budget-b...  43.489083  -1.457178
# 2  https://www.booking.com/hotel/fr/okko-hotels-b...  43.495344  -1.482512
# 3  https://www.booking.com/hotel/fr/cote-basque.f...  43.496183  -1.469601
# 4  https://www.booking.com/hotel/fr/villa-koegui-...  43.492371  -1.472588
#
#    score                                        description
# 0    8.1   Installé dans le centre-ville de Bayonne, en ...
# 1    7.7   L'hôtel ibis budget Bayonne est situé à 2 km ...
# 2    8.8   Situé à Bayonne, à seulement 700 mètres du ce...
# 3    8.1   L'Hotel Cote Basque est situé au cœur de la v...
# 4    8.9   Doté d’un bar, d’un restaurant, d’une terrass...

# %% [markdown]
# 2. Create and configure a RDS instance in your AWS account.
#
# 3. Use SQLAlchemy to create an engine that is connected to the remote database

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql+psycopg2://postgres_1986:****@"
                       "****/****", echo=True)

# %% [markdown]
# 4. Create two tables in your remote database : `cities` and `hotels`, each one containing the information from the different .csv files you saved yesterday

# %%
df_weather.to_sql('cities_weather', engine)
# Out:
# 2020-11-11 11:44:28,916 INFO sqlalchemy.engine.base.Engine select version()
# 2020-11-11 11:44:28,918 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:28,927 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2020-11-11 11:44:28,928 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:28,939 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-11-11 11:44:28,940 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:28,947 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-11-11 11:44:28,947 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:28,952 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2020-11-11 11:44:28,952 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:28,962 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-11 11:44:28,963 INFO sqlalchemy.engine.base.Engine {'name': 'cities_weather'}
# 2020-11-11 11:44:28,979 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE cities_weather (
# 	index BIGINT,
# 	city_id BIGINT,
# 	city_name TEXT,
# 	lat FLOAT(53),
# 	lon FLOAT(53),
# 	temperature FLOAT(53),
# 	main_weather TEXT,
# 	humidity FLOAT(53),
# 	expected_rain FLOAT(53),
# 	wind_speed FLOAT(53),
# 	"UV_indice" FLOAT(53),
# 	rank BIGINT,
# 	inverted_rank BIGINT
# )
#
#
# 2020-11-11 11:44:28,980 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:29,031 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-11 11:44:29,038 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_cities_weather_index ON cities_weather (index)
# 2020-11-11 11:44:29,039 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:29,052 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-11 11:44:29,060 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-11 11:44:29,061 INFO sqlalchemy.engine.base.Engine INSERT INTO cities_weather (index, city_id, city_name, lat, lon, temperature, main_weather, humidity, expected_rain, wind_speed, "UV_indice", rank, inverted_rank) VALUES (%(index)s, %(city_id)s, %(city_name)s, %(lat)s, %(lon)s, %(temperature)s, %(main_weather)s, %(humidity)s, %(expected_rain)s, %(wind_speed)s, %(UV_indice)s, %(rank)s, %(inverted_rank)s)
# 2020-11-11 11:44:29,062 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'city_id': 33, 'city_name': 'Bayonne', 'lat': 43.493338, 'lon': -1.475099, 'temperature': 18.51, 'main_weather': 'Clouds', 'humidity': 58.43, 'expected_rain': 0.5712, 'wind_speed': 1.68, 'UV_indice': 1.75, 'rank': 1, 'inverted_rank': 35}, {'index': 1, 'city_id': 32, 'city_name': 'Biarritz', 'lat': 43.471144, 'lon': -1.552727, 'temperature': 17.88, 'main_weather': 'Clouds', 'humidity': 61.0, 'expected_rain': 0.6106, 'wind_speed': 1.73, 'UV_indice': 1.74, 'rank': 2, 'inverted_rank': 34}, {'index': 2, 'city_id': 27, 'city_name': 'Collioure', 'lat': 42.52505, 'lon': 3.083155, 'temperature': 17.51, 'main_weather': 'Clear', 'humidity': 64.29, 'expected_rain': 0.1631, 'wind_speed': 2.4, 'UV_indice': 1.82, 'rank': 3, 'inverted_rank': 33}, {'index': 3, 'city_id': 15, 'city_name': 'Grenoble', 'lat': 45.18756, 'lon': 5.735782, 'temperature': 17.32, 'main_weather': 'Clouds', 'humidity': 48.86, 'expected_rain': 0.0, 'wind_speed': 0.86, 'UV_indice': 1.56, 'rank': 4, 'inverted_rank': 32}, {'index': 4, 'city_id': 19, 'city_name': 'Cassis', 'lat': 43.214036, 'lon': 5.539632, 'temperature': 17.25, 'main_weather': 'Clear', 'humidity': 61.71, 'expected_rain': 1.5052, 'wind_speed': 2.15, 'UV_indice': 1.76, 'rank': 5, 'inverted_rank': 31}, {'index': 5, 'city_id': 28, 'city_name': 'Carcassonne', 'lat': 43.213035999999995, 'lon': 2.349107, 'temperature': 17.16, 'main_weather': 'Clouds', 'humidity': 62.0, 'expected_rain': 0.0416, 'wind_speed': 4.04, 'UV_indice': 1.77, 'rank': 6, 'inverted_rank': 30}, {'index': 6, 'city_id': 22, 'city_name': 'Avignon', 'lat': 43.949249, 'lon': 4.805901, 'temperature': 17.1, 'main_weather': 'Clear', 'humidity': 58.86, 'expected_rain': 0.081, 'wind_speed': 1.51, 'UV_indice': 1.65, 'rank': 7, 'inverted_rank': 29}, {'index': 7, 'city_id': 30, 'city_name': 'Toulouse', 'lat': 43.604462, 'lon': 1.4442469999999998, 'temperature': 17.04, 'main_weather': 'Clouds', 'humidity': 58.29, 'expected_rain': 1.8468, 'wind_speed': 3.23, 'UV_indice': 1.7, 'rank': 8, 'inverted_rank': 28}  ... displaying 10 of 35 total bound parameter sets ...  {'index': 33, 'city_id': 7, 'city_name': 'Lille', 'lat': 50.636565000000004, 'lon': 3.063528, 'temperature': 12.76, 'main_weather': 'Rain', 'humidity': 73.71, 'expected_rain': 9.5673, 'wind_speed': 5.71, 'UV_indice': 0.88, 'rank': 34, 'inverted_rank': 2}, {'index': 34, 'city_id': 9, 'city_name': 'Chateau du Haut Koenigsbourg', 'lat': 48.24949, 'lon': 7.344296000000001, 'temperature': 11.33, 'main_weather': 'Clouds', 'humidity': 70.57, 'expected_rain': 0.6142, 'wind_speed': 1.68, 'UV_indice': 1.1, 'rank': 35, 'inverted_rank': 1})
# 2020-11-11 11:44:29,246 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
df_list_hotels.to_sql('hotels', engine)
# Out:
# 2020-11-11 11:44:50,616 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-11 11:44:50,617 INFO sqlalchemy.engine.base.Engine {'name': 'hotels'}
# 2020-11-11 11:44:50,639 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE hotels (
# 	index BIGINT,
# 	city_id BIGINT,
# 	city_name TEXT,
# 	"hotel id" BIGINT,
# 	"hotel name" TEXT,
# 	"hotel url" TEXT,
# 	latitude FLOAT(53),
# 	longitude FLOAT(53),
# 	score FLOAT(53),
# 	description TEXT
# )
#
#
# 2020-11-11 11:44:50,640 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:50,655 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-11 11:44:50,661 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_hotels_index ON hotels (index)
# 2020-11-11 11:44:50,662 INFO sqlalchemy.engine.base.Engine {}
# 2020-11-11 11:44:50,674 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-11-11 11:44:50,681 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-11-11 11:44:50,687 INFO sqlalchemy.engine.base.Engine INSERT INTO hotels (index, city_id, city_name, "hotel id", "hotel name", "hotel url", latitude, longitude, score, description) VALUES (%(index)s, %(city_id)s, %(city_name)s, %(hotel id)s, %(hotel name)s, %(hotel url)s, %(latitude)s, %(longitude)s, %(score)s, %(description)s)
# 2020-11-11 11:44:50,687 INFO sqlalchemy.engine.base.Engine ({'index': 0, 'city_id': 33, 'city_name': 'Bayonne', 'hotel id': 0, 'hotel name': ' Hôtel Le Bayonne ', 'hotel url': 'https://www.booking.com/hotel/fr/le-bayonne-ha-tel.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB0gIkY ... (148 characters truncated) ... ildren=0&hapos=1&hpos=1&no_rooms=1&sr_order=popularity&srepoch=1604998590&srpvid=3ce33edec3570043&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 43.4850261989896, 'longitude': -1.47537052631378, 'score': 8.1, 'description': " Installé dans le centre-ville de Bayonne, en Aquitaine, l'Hôtel Le Bayonne vous propose une piscine extérieure chauffée ouverte en saison ainsi qu'un hammam. "}, {'index': 1, 'city_id': 33, 'city_name': 'Bayonne', 'hotel id': 1, 'hotel name': ' ibis budget Bayonne ', 'hotel url': 'https://www.booking.com/hotel/fr/ibis-budget-bayonne.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB0gI ... (150 characters truncated) ... ildren=0&hapos=2&hpos=2&no_rooms=1&sr_order=popularity&srepoch=1604998590&srpvid=3ce33edec3570043&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 43.489082618638804, 'longitude': -1.4571780861297199, 'score': 7.7, 'description': " L'hôtel ibis budget Bayonne est situé à 2 km du centre historique de Bayonne et de sa gare ferroviaire ainsi qu'à 8 km des plages. "}, {'index': 2, 'city_id': 33, 'city_name': 'Bayonne', 'hotel id': 2, 'hotel name': ' Okko Hotels Bayonne Centre ', 'hotel url': 'https://www.booking.com/hotel/fr/okko-hotels-bayonne-centre.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0F ... (157 characters truncated) ... ildren=0&hapos=3&hpos=3&no_rooms=1&sr_order=popularity&srepoch=1604998590&srpvid=3ce33edec3570043&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 43.4953443, 'longitude': -1.4825118, 'score': 8.8, 'description': ' Situé à Bayonne, à seulement 700 mètres du centre-ville et de la cathédrale Sainte-Marie de Bayonne, l’Okko Hotels Bayonne Centre vous propose des chambres climatisées avec une connexion Wi-Fi... '}, {'index': 3, 'city_id': 33, 'city_name': 'Bayonne', 'hotel id': 3, 'hotel name': ' Hotel Cote Basque ', 'hotel url': 'https://www.booking.com/hotel/fr/cote-basque.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB0gIkYWJiOGR ... (142 characters truncated) ... ildren=0&hapos=4&hpos=4&no_rooms=1&sr_order=popularity&srepoch=1604998590&srpvid=3ce33edec3570043&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 43.4961830648043, 'longitude': -1.4696010947227498, 'score': 8.1, 'description': " L'Hotel Cote Basque est situé au cœur de la ville historique de Bayonne, en face du pont Saint-Esprit. Il propose une connexion Wi-Fi gratuite et des chambres avec salle de bains privative. "}, {'index': 4, 'city_id': 33, 'city_name': 'Bayonne', 'hotel id': 4, 'hotel name': ' Hôtel Villa KOEGUI Bayonne ', 'hotel url': 'https://www.booking.com/hotel/fr/villa-koegui-bayonne.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB0g ... (151 characters truncated) ... ildren=0&hapos=5&hpos=5&no_rooms=1&sr_order=popularity&srepoch=1604998590&srpvid=3ce33edec3570043&ucfs=1&from=searchresults;highlight_room=#hotelTmpl', 'latitude': 43.492371, 'longitude': -1.472588, 'score': 8.9, 'description': ' Doté d’un bar, d’un restaurant, d’une terrasse, d’un salon commun et d’une salle de sport, l’Hôtel Villa KOEGUI Bayonne propose des hébergements à Bayonne. '}, {'index': 5, 'city_id': 33, 'city_name': 'Bayonne', 'hotel id': 5, 'hotel name': ' Premiere Classe Bayonne ', 'hotel url': 'https://www.booking.com/hotel/fr/premiere-classe-bayonne.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAI ... (154 characters truncated) ... ildren=0&hapos=6&hpos=6&no_rooms=1&sr_order ...
# 2020-11-11 11:44:54,401 INFO sqlalchemy.engine.base.Engine COMMIT

# %% [markdown]
# 5. Optional : use PGAdmin to explore the database
#
# 6. Use SQL syntax to make a request that will help you get the list of the 30 best places to go (among all cities and hotels) 😎

# %%
from sqlalchemy.sql import text

conn = engine.connect()

stmt_30_best_places = text('SELECT cw.city_name, cw.main_weather, cw.temperature, '
                          'h."hotel name", h.score, h.description, h."hotel url" '
                          'FROM cities_weather as cw, hotels as h '
                          'WHERE cw.city_id = h.city_id '
                          'ORDER BY score DESC, temperature DESC '
                          'LIMIT 30'
                          )
                          # OR fetch first 30 rows only

res_30_best_place = conn.execute(stmt_30_best_place)
res_30_best_place.fetchall()
# Out:
# 2020-11-11 12:30:42,764 INFO sqlalchemy.engine.base.Engine SELECT cw.city_name, cw.main_weather, cw.temperature, h."hotel name", h.score, h.description, h."hotel url" FROM cities_weather as cw, hotels as h WHERE cw.city_id = h.city_id ORDER BY score DESC, temperature DESC LIMIT 30
# 2020-11-11 12:30:42,765 INFO sqlalchemy.engine.base.Engine {}
# [('Biarritz', 'Clouds', 17.88, ' Villa Uhaïna ', 10.0, ' La Villa Uhaïna est située sur le front de mer à Biarritz, à 1,1 km de la plage de la Côte des Basques et de celle de Marbella, dans une région propice à la randonnée. ', 'https://www.booking.com/hotel/fr/villa-milady.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB0gIkY2ZjZW ... (173 characters truncated) ... dren=0&hapos=402&hpos=2&no_rooms=1&sr_order=popularity&srepoch=1605037487&srpvid=17c68ad7938a0003&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' T2 au coeur de Bayonne ', 9.9, ' Offrant une vue sur la ville, le T2 au cœur de Bayonne est un hébergement situé à Bayonne, à 400 mètres de la cathédrale Sainte-Marie et à 1,2 km de la plaine d’Ansot. ', 'https://www.booking.com/hotel/fr/t2-au-coeur-de-bayonne.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB ... (155 characters truncated) ... dren=0&hapos=69&hpos=19&no_rooms=1&sr_order=popularity&srepoch=1604998592&srpvid=f8b03ee070ec0118&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' Bellevue ', 9.8, ' Le Bellevue est situé à Biarritz, à 500 mètres de la plage Port Vieux et à 800 mètres du rocher de la Vierge, dans une région où vous pourrez faire de la randonnée. ', 'https://www.booking.com/hotel/fr/bellevue-biarritz.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB0gIkY ... (177 characters truncated) ... ldren=0&hapos=59&hpos=9&no_rooms=1&sr_order=popularity&srepoch=1605037469&srpvid=d3178ace0d1c0145&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, " L'Etape, 2ch, Parking, 250m Gde Plage, tt à pieds ", 9.8, " L'Etape, 2ch, Parking met gratuitement à votre disposition une connexion Wi-Fi et un parking privé. Le Gde Plage, tt à pieds est situé à Biarritz, à seulement 1,6 km du rocher de la Vierge. ", 'https://www.booking.com/hotel/fr/etape-2ch-parking-250m-gde-plage-tt-a-pieds.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQK ... (204 characters truncated) ... dren=0&hapos=92&hpos=17&no_rooms=1&sr_order=popularity&srepoch=1605037470&srpvid=a1578acf4f62004f&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' JUST LIKE HOME BIARRITZ - Private Parking - Free E-Bikes - Welcome Breakfast ', 9.8, ' Offrant une vue sur le jardin, le JUST LIKE HOME BIARRITZ vous accueille à Biarritz, à 1,4 km de la plage Port Vieux et à 2,1 km du rocher de la Vierge. ', 'https://www.booking.com/hotel/fr/appartement-standing-biarritz.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq ... (190 characters truncated) ... dren=0&hapos=50&hpos=25&no_rooms=1&sr_order=popularity&srepoch=1605037468&srpvid=9d238acd215a0128&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Collioure', 'Clear', 17.51, ' Les mimosas ', 9.8, ' Doté d’un jardin et d’une piscine extérieure privée ouverte en saison, l’hébergement Les mimosas se trouve à Collioure, à 650 mètres de la plage de Port d’Avall. Sa réception est ouverte 24h/24. ', 'https://www.booking.com/hotel/fr/les-mimosas-collioure.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4AqCrqf0FwAIB0 ... (182 characters truncated) ... dren=0&hapos=23&hpos=23&no_rooms=1&sr_order=popularity&srepoch=1604998562&srpvid=1cac3ed1aa1800a2&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Collioure', 'Clear', 17.51, ' Boramar ', 9.8, ' Situé à Collioure, à quelques pas de la plage de Boramar et à 100 mètres de la plage Nord, le Boramar est un hébergement climatisé bénéficiant d’une connexion Wi-Fi gratuite, d’un restaurant et d’une... ', 'https://www.booking.com/hotel/fr/boramar.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4AqCrqf0FwAIB0gIkY2Y2ZjE2YzU ... (168 characters truncated) ... dren=0&hapos=60&hpos=10&no_rooms=1&sr_order=popularity&srepoch=1604998565&srpvid=a7953ed21de20069&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Collioure', 'Clear', 17.51, ' Les Hauts de Collioure ', 9.8, " Doté d'une piscine extérieure ouverte en saison, d'un jardin et d'un barbecue, l'établissement Les Hauts de Collioure propose un hébergement avec une connexion Wi-Fi gratuite et une vue sur la mer à... ", 'https://www.booking.com/hotel/fr/les-hauts-de-collioure-collioure1.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4A ... (194 characters truncated) ... dren=0&hapos=153&hpos=3&no_rooms=1&sr_order=popularity&srepoch=1604998570&srpvid=63b13ed494bd0007&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' Duplex avec belle térasse au centre de Bayonne ', 9.7, ' Duplex avec belle térasse au centre de Bayonne, a property with a terrace, is set in Bayonne, less than 1 km from Saint Marie Cathedral, 1.7 km from Ansot Park, as well as 400 metres from Musee... ', 'https://www.booking.com/hotel/fr/duplex-avec-belle-terasse-au-centre-de-bayonne.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4 ... (179 characters truncated) ... dren=0&hapos=70&hpos=20&no_rooms=1&sr_order=popularity&srepoch=1604998592&srpvid=f8b03ee070ec0118&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' UNIQUE APPARTEMENT TYPE HAUSSMANIEN - BAYONNE CENTRE ', 9.7, ' Donnant sur la rivière, l’UNIQUE APPARTEMENT TYPE HAUSSMANIEN - BAYONNE CENTRE est un hébergement doté d’un balcon et d’une bouilloire. Vous séjournerez à environ 2,8 km de la cathédrale Sainte-Marie.... ', 'https://www.booking.com/hotel/fr/unique-appartement-type-haussmanien-bayonne-centre.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHo ... (183 characters truncated) ... dren=0&hapos=43&hpos=18&no_rooms=1&sr_order=popularity&srepoch=1604998591&srpvid=af303edf5458005d&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' Large and confortable apartment on Bayonne city-center ', 9.7, ' Le Welkeys - Bayonne Old City 3br Apartment propose un hébergement avec connexion Wi-Fi gratuite à Bayonne, à 2,6 km de la cathédrale Sainte-Marie, à 3,7 km du parc Ansot et à 300 mètres du jardin... ', 'https://www.booking.com/hotel/fr/large-and-confortable-apartment-on-bayonne-city-center.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjY ... (187 characters truncated) ... dren=0&hapos=47&hpos=22&no_rooms=1&sr_order=popularity&srepoch=1604998591&srpvid=af303edf5458005d&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, " La Chambre d'Hote de Mano - Centre-ville de Bayonne ", 9.7, " Situé à 200 mètres de la gare de Bayonne, à moins de 2 minutes à pied des berges de l'Adour et à 1 km de la cathédrale, l'établissement La Chambre d'Hote De Mano - Centre-ville de Bayonne vous propose... ", 'https://www.booking.com/hotel/fr/chambre-d-39-hotes-de-bayonne-france.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAg ... (168 characters truncated) ... ldren=0&hapos=52&hpos=2&no_rooms=1&sr_order=popularity&srepoch=1604998592&srpvid=f8b03ee070ec0118&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' Home Saint-Jean ', 9.7, ' Le Home Saint-Jean propose un appartement avec vue sur la montagne situé à 1,1 km du rocher de la Vierge et à 550 mètres de la plage. ', 'https://www.booking.com/hotel/fr/home-saint-jean.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB0gIkY2Z ... (176 characters truncated) ... dren=0&hapos=89&hpos=14&no_rooms=1&sr_order=popularity&srepoch=1605037470&srpvid=a1578acf4f62004f&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' En Face de la Plage du Port Vieux ', 9.7, " Situé à Biarritz, l'établissement En Face de la Plage du Port Vieux propose un hébergement avec connexion Wi-Fi gratuite, à 300 mètres du rocher de la Vierge et à 100 mètres de la Villa Beltza. ", 'https://www.booking.com/hotel/fr/port-vieux-en-face-de-la-mer-avec-jardin-privatif.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoA ... (210 characters truncated) ... dren=0&hapos=226&hpos=1&no_rooms=1&sr_order=popularity&srepoch=1605037478&srpvid=17d68ad3a15d0162&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, " Maison du Lavoir d'Ilbarritz ", 9.7, " La Maison du Lavoir d'Ilbarritz propose un hébergement à Biarritz, à 3,5 km du rocher de la Vierge. Il offre une vue sur le jardin et se trouve à 500 mètres de la Cité de l'Océan. ", 'https://www.booking.com/hotel/fr/maison-du-lavoir-d-39-ilbarritz.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apj ... (193 characters truncated) ... ren=0&hapos=212&hpos=12&no_rooms=1&sr_order=popularity&srepoch=1605037477&srpvid=76258ad2a71e00b2&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' T2 Sunset ', 9.7, ' Offrant une vue sur la mer, le T2 Sunset est un hébergement situé à Biarritz, à seulement 350 mètres de la plage Miramar et de celle du VVF. ', 'https://www.booking.com/hotel/fr/t2-sunset.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB0gIkY2ZjZWI2O ... (170 characters truncated) ... dren=0&hapos=183&hpos=8&no_rooms=1&sr_order=popularity&srepoch=1605037476&srpvid=f6f28ad1cd54015d&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' Charming and design flat at the heart of Biarritz near the beach - Welkeys ', 9.7, ' Le Charming and design flat at the heart of Biarritz, near the beach - Welkeys est situé dans le centre-ville de Biarritz, à moins de 1 km de la plage du Port-Vieux, à 1,2 km du rocher de la Vierge et... ', 'https://www.booking.com/hotel/fr/charming-and-design-flat-at-the-heart-of-biarritz-near-the-beach-welkeys.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE ... (233 characters truncated) ... dren=0&hapos=72&hpos=22&no_rooms=1&sr_order=popularity&srepoch=1605037469&srpvid=d3178ace0d1c0145&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' T3 cosy avec Balcon proche du centre Biarritz ', 9.7, ' Boasting city views, T3 cosy avec Balcon proche du centre Biarritz offers accommodation with a balcony and a coffee machine, around 1.7 km from Plage Port Vieux. ', 'https://www.booking.com/hotel/fr/t3-avec-balcon-proche-du-centre-de-biarritz.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQK ... (205 characters truncated) ... ren=0&hapos=120&hpos=20&no_rooms=1&sr_order=popularity&srepoch=1605037472&srpvid=c2558acf6b200002&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' VILLA MARGA ', 9.7, ' La VILLA MARGA est un hébergement situé à Biarritz, à 1,3 km du rocher de la Vierge et à 80 mètres de la médiathèque. Sur place, vous bénéficierez d’une connexion Wi-Fi gratuite. ', 'https://www.booking.com/hotel/fr/villa-marga.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB0gIkY2ZjZWI ... (173 characters truncated) ... ren=0&hapos=141&hpos=16&no_rooms=1&sr_order=popularity&srepoch=1605037473&srpvid=0bc08ad0851301a2&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' Péniche DJEBELLE ', 9.6, ' Située à Bayonne, à moins de 2,3 km de la cathédrale Sainte-Marie et à 3,1 km du parc Ansot, la Péniche DJEBELLE dispose d’un salon commun, d’une terrasse et d’une connexion Wi-Fi gratuite. ', 'https://www.booking.com/hotel/fr/peniche-djebelle.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB0gIkYW ... (148 characters truncated) ... ldren=0&hapos=26&hpos=1&no_rooms=1&sr_order=popularity&srepoch=1604998591&srpvid=af303edf5458005d&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' residence saint bernard ', 9.6, ' Offrant une vue sur le jardin, la residence saint bernard propose des hébergements avec une terrasse et une bouilloire, à environ 2,5 km du parc Ansot. ', 'https://www.booking.com/hotel/fr/residence-saint-bernard.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAI ... (155 characters truncated) ... ldren=0&hapos=31&hpos=6&no_rooms=1&sr_order=popularity&srepoch=1604998591&srpvid=af303edf5458005d&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' Villa Kittera, Seaview ', 9.6, ' Située à Biarritz, la Villa Kittera, Seaview propose une connexion Wi-Fi gratuite dans l’ensemble des locaux, une salle de sport, une cuisine et un salon communs, ainsi qu’un jardin. ', 'https://www.booking.com/hotel/fr/villa-kittera.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB0gIkY2ZjZ ... (175 characters truncated) ... ren=0&hapos=341&hpos=16&no_rooms=1&sr_order=popularity&srepoch=1605037483&srpvid=ae198ad5e1990049&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' Appartement Halles de Biarritz ', 9.6, " L'Appartement Halles de Biarritz est situé dans le centre de Biarritz, à seulement 500 mètres de la plage du Port Vieux et à 1,3 km du rocher de la Vierge. ", 'https://www.booking.com/hotel/fr/christina-biarritz.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB0gIk ... (180 characters truncated) ... ren=0&hapos=162&hpos=12&no_rooms=1&sr_order=popularity&srepoch=1605037474&srpvid=cec88ad1c25001cc&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Biarritz', 'Clouds', 17.88, ' Maison Basque ', 9.6, ' Offrant une vue sur son jardin, la Maison Basque est située à moins de 1 km de la plage du VVF. Cette maison de vacances possède une terrasse et un barbecue. ', 'https://www.booking.com/hotel/fr/maison-basque-biarritz.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Apjbq_0FwAIB ... (182 characters truncated) ... ldren=0&hapos=84&hpos=9&no_rooms=1&sr_order=popularity&srepoch=1605037470&srpvid=a1578acf4f62004f&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Collioure', 'Clear', 17.51, ' Michelet ', 9.6, ' Situé à Collioure, à 700 mètres du château royal et à 3 km du casino, le Michelet propose un hébergement climatisé avec une terrasse et une connexion Wi-Fi gratuite. ', 'https://www.booking.com/hotel/fr/michelet-collioure.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4AqCrqf0FwAIB0gIk ... (179 characters truncated) ... dren=0&hapos=50&hpos=25&no_rooms=1&sr_order=popularity&srepoch=1604998564&srpvid=6cce3ed19da50002&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Collioure', 'Clear', 17.51, ' 3 Rue Marceau ', 9.6, ' Situé à Collioure, à 2,6 km de la plage de Racou et à 600 mètres du château royal de Collioure, le 3 Rue Marceau dispose de la climatisation. ', 'https://www.booking.com/hotel/fr/3-rue-marceau.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4AqCrqf0FwAIB0gIkY2Y2Z ... (174 characters truncated) ... dren=0&hapos=69&hpos=19&no_rooms=1&sr_order=popularity&srepoch=1604998565&srpvid=a7953ed21de20069&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' Appartement au calme proximité centre ', 9.5, " Offrant une vue sur le jardin, l'Appartement au calme proximité centre est situé à Bayonne, à 3,6 km du tribunal de grande instance et à 3,8 km de l'hôtel de ville. ", 'https://www.booking.com/hotel/fr/appartement-au-calme-proximite-centre.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoA ... (169 characters truncated) ... ldren=0&hapos=58&hpos=8&no_rooms=1&sr_order=popularity&srepoch=1604998592&srpvid=f8b03ee070ec0118&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' 23 Avenue du 8 Mai 1945 ', 9.5, " Situé à Bayonne, à seulement 1,9 km du parc Ansot, le 23 Avenue du 8 Mai 1945 propose un hébergement avec vue sur la rivière. Vous bénéficierez gratuitement d'une connexion Wi-Fi et d'un parking... ", 'https://www.booking.com/hotel/fr/23-avenue-du-8-mai-1945.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAI ... (155 characters truncated) ... ldren=0&hapos=59&hpos=9&no_rooms=1&sr_order=popularity&srepoch=1604998592&srpvid=f8b03ee070ec0118&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' Euskal etxea ', 9.5, " Doté d'une terrasse avec vue sur le jardin, d'un jardin et d'un barbecue, l'Euskal etxea se trouve à Bayonne. Il vous accueille à proximité du siège de Guyenne et Gascogne et à 3 km du parc Ansot. ", 'https://www.booking.com/hotel/fr/euskal-etxea.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB0gIkYWJiOG ... (145 characters truncated) ... dren=0&hapos=36&hpos=11&no_rooms=1&sr_order=popularity&srepoch=1604998591&srpvid=af303edf5458005d&ucfs=1&from=searchresults;highlight_room=#hotelTmpl'),
#  ('Bayonne', 'Clouds', 18.51, ' 5 Rue des Faures ', 9.5, ' Offrant une vue sur la ville, le 5 Rue des Faures propose un hébergement avec une terrasse et une bouilloire, à environ 200 mètres de la cathédrale Sainte-Marie. ', 'https://www.booking.com/hotel/fr/5-rue-des-faures.fr.html?label=gen173nr-1FCAEoggI46AdIDVgEaE2IAQGYAQ24AQrIAUjYAQHoAQH4AQKIAgGoAgO4Aryrqf0FwAIB0gIkYW ... (148 characters truncated) ... ldren=0&hapos=32&hpos=7&no_rooms=1&sr_order=popularity&srepoch=1604998591&srpvid=af303edf5458005d&ucfs=1&from=searchresults;highlight_room=#hotelTmpl')]

# %%
df_30_best_places = pd.read_sql(stmt_30_best_places, engine)
df_30_best_places
# Out:
# 2020-11-11 12:28:10,578 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2020-11-11 12:28:10,579 INFO sqlalchemy.engine.base.Engine {'name': 'SELECT cw.city_name, cw.main_weather, cw.temperature, h."hotel name", h.score, h.description, h."hotel url" FROM cities_weather as cw, hotels as h WHERE cw.city_id = h.city_id ORDER BY score DESC, temperature DESC LIMIT 30'}
# 2020-11-11 12:28:10,604 INFO sqlalchemy.engine.base.Engine SELECT cw.city_name, cw.main_weather, cw.temperature, h."hotel name", h.score, h.description, h."hotel url" FROM cities_weather as cw, hotels as h WHERE cw.city_id = h.city_id ORDER BY score DESC, temperature DESC LIMIT 30
# 2020-11-11 12:28:10,604 INFO sqlalchemy.engine.base.Engine {}
#     city_name main_weather  temperature  \
# 0    Biarritz       Clouds        17.88
# 1     Bayonne       Clouds        18.51
# 2    Biarritz       Clouds        17.88
# 3    Biarritz       Clouds        17.88
# 4    Biarritz       Clouds        17.88
# 5   Collioure        Clear        17.51
# 6   Collioure        Clear        17.51
# 7   Collioure        Clear        17.51
# 8     Bayonne       Clouds        18.51
# 9     Bayonne       Clouds        18.51
# 10    Bayonne       Clouds        18.51
# 11    Bayonne       Clouds        18.51
# 12   Biarritz       Clouds        17.88
# 13   Biarritz       Clouds        17.88
# 14   Biarritz       Clouds        17.88
# 15   Biarritz       Clouds        17.88
# 16   Biarritz       Clouds        17.88
# 17   Biarritz       Clouds        17.88
# 18   Biarritz       Clouds        17.88
# 19    Bayonne       Clouds        18.51
# 20    Bayonne       Clouds        18.51
# 21   Biarritz       Clouds        17.88
# 22   Biarritz       Clouds        17.88
# 23   Biarritz       Clouds        17.88
# 24  Collioure        Clear        17.51
# 25  Collioure        Clear        17.51
# 26    Bayonne       Clouds        18.51
# 27    Bayonne       Clouds        18.51
# 28    Bayonne       Clouds        18.51
# 29    Bayonne       Clouds        18.51
#
#                                            hotel name  score  \
# 0                                       Villa Uhaïna    10.0
# 1                             T2 au coeur de Bayonne     9.9
# 2                                           Bellevue     9.8
# 3    L'Etape, 2ch, Parking, 250m Gde Plage, tt à p...    9.8
# 4    JUST LIKE HOME BIARRITZ - Private Parking - F...    9.8
# 5                                        Les mimosas     9.8
# 6                                            Boramar     9.8
# 7                             Les Hauts de Collioure     9.8
# 8     Duplex avec belle térasse au centre de Bayonne     9.7
# 9    UNIQUE APPARTEMENT TYPE HAUSSMANIEN - BAYONNE...    9.7
# 10   Large and confortable apartment on Bayonne ci...    9.7
# 11   La Chambre d'Hote de Mano - Centre-ville de B...    9.7
# 12                                   Home Saint-Jean     9.7
# 13                 En Face de la Plage du Port Vieux     9.7
# 14                      Maison du Lavoir d'Ilbarritz     9.7
# 15                                         T2 Sunset     9.7
# 16   Charming and design flat at the heart of Biar...    9.7
# 17     T3 cosy avec Balcon proche du centre Biarritz     9.7
# 18                                       VILLA MARGA     9.7
# 19                                  Péniche DJEBELLE     9.6
# 20                           residence saint bernard     9.6
# 21                            Villa Kittera, Seaview     9.6
# 22                    Appartement Halles de Biarritz     9.6
# 23                                     Maison Basque     9.6
# 24                                          Michelet     9.6
# 25                                     3 Rue Marceau     9.6
# 26             Appartement au calme proximité centre     9.5
# 27                           23 Avenue du 8 Mai 1945     9.5
# 28                                      Euskal etxea     9.5
# 29                                  5 Rue des Faures     9.5
#
#                                           description  \
# 0    La Villa Uhaïna est située sur le front de me...
# 1    Offrant une vue sur la ville, le T2 au cœur d...
# 2    Le Bellevue est situé à Biarritz, à 500 mètre...
# 3    L'Etape, 2ch, Parking met gratuitement à votr...
# 4    Offrant une vue sur le jardin, le JUST LIKE H...
# 5    Doté d’un jardin et d’une piscine extérieure ...
# 6    Situé à Collioure, à quelques pas de la plage...
# 7    Doté d'une piscine extérieure ouverte en sais...
# 8    Duplex avec belle térasse au centre de Bayonn...
# 9    Donnant sur la rivière, l’UNIQUE APPARTEMENT ...
# 10   Le Welkeys - Bayonne Old City 3br Apartment p...
# 11   Situé à 200 mètres de la gare de Bayonne, à m...
# 12   Le Home Saint-Jean propose un appartement ave...
# 13   Situé à Biarritz, l'établissement En Face de ...
# 14   La Maison du Lavoir d'Ilbarritz propose un hé...
# 15   Offrant une vue sur la mer, le T2 Sunset est ...
# 16   Le Charming and design flat at the heart of B...
# 17   Boasting city views, T3 cosy avec Balcon proc...
# 18   La VILLA MARGA est un hébergement situé à Bia...
# 19   Située à Bayonne, à moins de 2,3 km de la cat...
# 20   Offrant une vue sur le jardin, la residence s...
# 21   Située à Biarritz, la Villa Kittera, Seaview ...
# 22   L'Appartement Halles de Biarritz est situé da...
# 23   Offrant une vue sur son jardin, la Maison Bas...
# 24   Situé à Collioure, à 700 mètres du château ro...
# 25   Situé à Collioure, à 2,6 km de la plage de Ra...
# 26   Offrant une vue sur le jardin, l'Appartement ...
# 27   Situé à Bayonne, à seulement 1,9 km du parc A...
# 28   Doté d'une terrasse avec vue sur le jardin, d...
# 29   Offrant une vue sur la ville, le 5 Rue des Fa...
#
#                                             hotel url
# 0   https://www.booking.com/hotel/fr/villa-milady....
# 1   https://www.booking.com/hotel/fr/t2-au-coeur-d...
# 2   https://www.booking.com/hotel/fr/bellevue-biar...
# 3   https://www.booking.com/hotel/fr/etape-2ch-par...
# 4   https://www.booking.com/hotel/fr/appartement-s...
# 5   https://www.booking.com/hotel/fr/les-mimosas-c...
# 6   https://www.booking.com/hotel/fr/boramar.fr.ht...
# 7   https://www.booking.com/hotel/fr/les-hauts-de-...
# 8   https://www.booking.com/hotel/fr/duplex-avec-b...
# 9   https://www.booking.com/hotel/fr/unique-appart...
# 10  https://www.booking.com/hotel/fr/large-and-con...
# 11  https://www.booking.com/hotel/fr/chambre-d-39-...
# 12  https://www.booking.com/hotel/fr/home-saint-je...
# 13  https://www.booking.com/hotel/fr/port-vieux-en...
# 14  https://www.booking.com/hotel/fr/maison-du-lav...
# 15  https://www.booking.com/hotel/fr/t2-sunset.fr....
# 16  https://www.booking.com/hotel/fr/charming-and-...
# 17  https://www.booking.com/hotel/fr/t3-avec-balco...
# 18  https://www.booking.com/hotel/fr/villa-marga.f...
# 19  https://www.booking.com/hotel/fr/peniche-djebe...
# 20  https://www.booking.com/hotel/fr/residence-sai...
# 21  https://www.booking.com/hotel/fr/villa-kittera...
# 22  https://www.booking.com/hotel/fr/christina-bia...
# 23  https://www.booking.com/hotel/fr/maison-basque...
# 24  https://www.booking.com/hotel/fr/michelet-coll...
# 25  https://www.booking.com/hotel/fr/3-rue-marceau...
# 26  https://www.booking.com/hotel/fr/appartement-a...
# 27  https://www.booking.com/hotel/fr/23-avenue-du-...
# 28  https://www.booking.com/hotel/fr/euskal-etxea....
# 29  https://www.booking.com/hotel/fr/5-rue-des-fau...
